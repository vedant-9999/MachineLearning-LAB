# %%
#To implement K Nearest neighbours
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
#Small Sample Dataset(2D points)
#Features: [height (cm), weight (kg)]


X = [
    [150, 50],
    [160, 60],
    [170, 65],
    [180, 80],
    [190, 85],
    [200, 90]

]

# %%
# Labels: 0 = Class A, 1 = Class B
y = [0,0,0,1,1,1]

# %%
#Create and train the model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#Test on new points
X_test = [
    [155, 55],
    [185, 82]
]
y_test = [0,1]

# %%
#Predict
y_pred = knn.predict(X_test)
print("Predictions: ", y_pred)
# Out:
# Predictions:  [0 1]

# %%
#Evaluate using confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
display_labels=[ConfusionMatrixDisplay]
disp.plot()
plt.title("Confusion Matrix")
plt.show()

# %%
new_row = [175,60]
X.append(new_row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4095533544.py in <cell line: 0>()
#       1 new_row = [175,60]
# ----> 2 X.append(new_row)
#
# NameError: name 'X' is not defined
